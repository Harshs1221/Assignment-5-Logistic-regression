# %%
#Q1.  What is Logistic Regression, and how does it differ from Linear Regression?
"""
Ans1. Logistic regression is used for classification problems. Instead of predicting continous output,
      it predicts the probability that an observation belongs to particular class (e.g., yes/np, spam/not spam).
      where as linear regression is used for predicting continous values. It assumes a linear relationship
      between the dependent variable and independent variable.

      For example:
      Linear regression:
          Imagine you are trying to predict a monthly salary based on the years of experience.
          - If you plot experience vs salary, you'll likely to see a trend where more experience means higher
            salary.
          - Linear regression fits a straight-line equation to estimate salaries.
      Logistic regression:
          Now, imagine you run a company and want to predict whether a job applicant will be hired or not
          (Yes or No) based on experience.
          - You cant use staright- line beacuse hiring not a number, its yes/no decision.
          - Logistic regression calculates probabilities and classifies aplicants.
"""

# %%
#Q2.  What is the mathematical equation of Logistic Regression?
"""
Ans2. 𝑃(𝑌=1)= 1/+𝑒**-(𝑏0+𝑏1𝑋1+b2𝑋+...+𝑏𝑛𝑋𝑛)
"""

# %%
#Q3. Why do we use the Sigmoid function in Logistic Regression?
"""
Ans3. We use sigmoid function in logistic regression because:
        - Sigmoid function solve outlier problem:
                    It reduces the impact of extreme values by squashing them into a limited range.
        - Keep output in Range(0 tp 1):
                    Since classification requires probabilitoes, the sigmoid function ensures predictions
                    stay between 0 to 1.
        - Prediction chnages gradually
                    Instead of abrupt shifts, the sigmoid function helps prediction chnages smoothly
                    as input values vary.
"""

# %%
#Q4. What is the cost function of Logistic Regression?
"""
Ans4. The cost function in logistic regression is used to measure how well the model's predictions match the
      actual values.
      Since the logistic regression deals with classification, we use a speical cost function called log loss
      or Binary Cross-Entropy.

      Cost function = 𝐽(𝜃)=−[𝑦log(ℎ𝜃(𝑥)) + (1−𝑦)log⁡(1−ℎ𝜃(𝑥))]
                  where y is actual value
                       ℎ𝜃(𝑥) is the predicted proabability from the logistic regression model 
"""

# %%
#Q5.  What is Regularization in Logistic Regression? Why is it needed?
"""
Ans5. Regularization in Logistic Regression is a technique used to prevent overfitting by adding a penalty to the
      model's complexity.
      It ensures the model generalizes well to unseen data instaed of memorizing the training data.

      Why is it needed?
      - Reduces Overfitting(L2 regularization (ridge)):
              Prevents the model from learning noise and irrelevant patterns.
      - Feature Selection (L1 regularization (lasso)):
              Helps eliminate less useful features by shrinking their coefficients.
      - Improves Generalization:
              Ensures better performance on new, unseen data.
"""

# %%
#Q6.  Explain the difference between Lasso, Ridge, and Elastic Net regression?
"""
Ans6. Lasso Regression (L1 Regularization):
        - Adds the absolute values of coefficients as a penalty.
        - Some coefficients shrink to zero, effectively removing less important features.
        - Useful when you want automatic feature selection.

      Ridge regression (L2 Regularization)
        - Adds the squared values of coefficients as a penalty.
        - Reduces coefficient magnitides biy does not eliminate features.
        - Helps when features are highly correlated.

      Elastic Net Regression
        - Combines L1 and L2 regularization.
        - Useful when there are many correlated features.
        - Provide a balance between feature selection (Lasso) and coefficient shrinkage (Ridge).
"""

# %%
#Q7.  When should we use Elastic Net instead of Lasso or Ridge?
"""
Ans7. Elastic net is used when you want a balance between feature selection and coefficient shrinkage.
      When to use Elastic net:
        When Lasso is removing too many features - Elastic net keeps the important ones.
        When features are highly correlated- It balances between feature selection and keeping useful features.
        When Ridge alone is too weak in reducing complexity - Elastic net provides a stringer regularization.
"""

# %%
#Q8. What is the impact of the regularization parameter (λ) in Logistic Regression?
"""
Ans8. (λ) lambda is a hyper paramter in logistic regression.
        A hyper parameter is a value that is set before training(not learned from the data). Since (λ) controls 
        regularization strength, chossing the right value is crucial.

        Tuning (λ) using techniques like Grid Search and or Cross validation helps find the best balance between
        overfitting and underfitting.

        Chossing the right (λ):
        - Too small - Overfitting (high variance)
        - Too large - Underfitting (high bias)
        - Optimal λ - balanced bias and variance for better performance.
"""

# %%
#Q9 What are the key assumptions of Logistic Regression?
"""
Ans9. The key assumption of logistic regression are:
        1. The outcome should be categorical:
                    Logistic Regression is used to predict categories like Yes/No or Win/Lose.
        2. Independent Observation:
                    Each data should not dependent on the others.
        3. Linear relationship with log-odds:
                    The input variables should affect the likelihood of the outcome in a predctiable way.
        4. No strong correlation between inputs:
                    Too much similarity between variables can confuse the model.
        5. Enough data:
                    Logistic Regression works best when there are sufficient examples learn from.
"""

# %%
#Q10.  What are some alternatives to Logistic Regression for classification tasks?
"""
Ans10. There are several alternatives to logistic regression for classification tasks, depending on the nature of your
       data and the complexity of the problem.

       1. Decision Tree
       2. Random Forest
       3. Support Vector Machines
       4. K-Nearest Neighbors (KNN)
       5. Naive bayes
       6. Neural Networks
       7. Gradient Bossting
       8. Poisson Regression & Log- Binomial Regression
"""

# %%
#Q11. What are Classification Evaluation Metrics?
"""
Ans11. Classification evaluation metrics help measure how well a model is performing in predicting
       categories. Here are some key metrics:

       1. Accuracy:
               The percentage of correct prediction out of total prediction.
       2. Precision:
               Measures how many of the predicted positive cases were actually positive.
       3. Recall(Senstivity):
               Measures how well the model identifies actual positive cases.
       4. Confusion Metrix:
               A table showing correct and incorrect predictions for each class.
       5. F1 Score:
               A balance between precision and recall useful when data is imbalanced.
       6. Auc-Roc Curve:
               Evaluates how well the model distinguishes between classes.
       7. Log Loss- 
               Measures the uncertainity of predictions, lower values indicates bettter performance.
"""

# %%
#Q12.  How does class imbalance affect Logistic Regression?
"""
Ans12. Class imbalance can significantly impact logistic regression it will give biased predictions, If one class has
       way more data than the other, the model may favour it and ignore the smaller class.
       2. Skewed Probability Estimates :
               The predicted probabilities may not be reliable, as the model learns patterns mostly from the dominant class.

        Effect:
            The model might have high accuracy overall but struggle to correctly predict the minority class.
        Solution:
            You can balance the data by adjusting class weights, using better evaluation metrics(like precision & recall),
            or applying techniques like oversampling / undersampling.
"""

# %%
#Q13.  What is Hyperparameter Tuning in Logistic Regression?
"""
Ans13. Hyperparameter tuning in Logistic Regression means adjusting certain settings to improve the model's performance.
        Some key ones include:
        1. Regularization Strength(C) - 
                Controls how much the model avoids Overfitting.
        2. Solver -
                Decides the method used to find the best model parameters.
        3. Penalty Type(L1 or L2) - 
                Helps prevent the model for becoming too complex.
        4. Max Iterations - 
                Sets how many times the model updates before stopping.

"""

# %%
#Q14. What are different solvers in Logistic Regression? Which one should be used?
"""
Ans14. Logistic Regression offers several solvers:
        1. Liblinear -
                Best for small to medium-sized datasets and supports L1 and L2 regularization.
        2. LBFGS -
                Works well for large datasets and supports L2 regularization.
        3.Newton-CG
                Suitable for datasets with many features, but mainly supports L2 regularization.
        4. SAG (Stochastic Average Gradient) -
                Efficient for large datasets but require L2 regularization.
        5. SAGA -
                Similar to SAG but supports both L1 and L2 regularization, making it useful for sparse data.
         Which one to use:
         1. If your dataset is small, use liblinear.
         2. If your dataset is large, use LBFGS, SAG, pr SAGA
         3. If you have many Fatures, try newton-CG
         4. If your data is sparse, SAGA is a good choice.
"""

# %%
#Q15.  How is Logistic Regression extended for multiclass classification?
"""
Ans15. Logistic Regression is usually used for two class problem (like Yes/No), but it can be extended for
       multiclass classification using these methods:

       1. One-vs-Rest (OvR) -
               The model creates separate classifiers for each class and picks the one with the highest probability.
       2. One-vs-One (OvO) -
                The model builds classifiers for every pair of classes and decides based on majority voting.
       3. Multinomial Logistic Regession - 
                Instead of breaking the problem into multiple binary classifications, it directly predicts
                probabilities for all classes using the softmax function.
       
"""

# %%
#Q16. What are the advantages and disadvantages of Logistic Regression?
"""
Ans16.  Advantages:
        1. Simple and Easy to Interpret - 
                It's straightforward and provides clear insights into how variables affect the outcome.
        2. Fast & Efficient - 
                Works well on small to medium-sized datasets and trains quickly.
        3. Handles both Continous and categorical Data -
                Can work with different types of input variables.
        4. Probabilistic Predictions -
                Outputs probabilities, making it useful for decision making.
        5. Less Prone to overfitting -
                With proper regularization, it avoids excessice complexity.
        6. Works well for Linearity Spearable Data -
                Performs best when the relationship between variables is roughly linear.
                
        Disadvantages:
        1. Assumes Linearity:
                It struggles when the relationship between variables is non-linear.
        2. Sensitive to Outliers -
                Extreme values can disort predictions.
        3. Limited Complexity -
                Not ideal for capturing complex pattern in data.
        4. Struggles with High-Dimensional Data -
                Peformance drops when there are too many features.
        5. Requires Feature Engineering -
                Needs well-prepared input data for optimal results.
"""

# %%
#Q17.  What are some use cases of Logistic Regression?
"""
Ans17. Use cases od lOgistic Regression are:
        1. Medical Diagnosis -
                Predicting diseases like diabetes or heart disease based on data.
        2. Fraud Detection -
                Identifying farudlent transaction in banking or not.
        3. Spam filtering -
                Classifying emails as spam or not not spam.
        4. Marketing and Advertising -
                Predicting whether a customer will click on an ad or make a purchase.
"""

# %%
#Q18 What is the difference between Softmax Regression and Logistic Regression?
"""
Ans18. - Logistic regression is used for two class problems (like Yes/ No)
       - Softmax Regression is used for multi-class problems (like class A,B or C)
       - Logistic Regressio uses the sigmoid function, which gives a probability between 0 and 1.
       - Softamx Regression uses the softmax function, which assigns probabilites to multiple classes,
         ensuring they sum to 1.
"""

# %%
#Q19. How do we choose between One-vs-Rest (OvR) and Softmax for multiclass classification?
"""
Ans19. You can choose betwenn OvR and softmax for multiclass classification by:
        1. Use OvR when you have few classes and want a simple, easy-to-understand model.
        2. Use Softmax when you have many classes and need a more efficient approach.
        3. If your dataset is imbalanced, OvR might work better.
        4. If you need proabilities across all classes, Softmax is the better choice.
"""

# %%
#Q20.  How do we interpret coefficients in Logistic Regression?
"""
Ans20. In Logistic Regression, coefficients tell us how each input variable affects the outcome:
        1. Positive coefficient -
                Increases the chance of the event happening.
        2. Negative Coefficient -
                Decreases the chance of the event happening.
        3. Bigger number -
                Stronger effect on the outcome.
        4. Odds Ratio -
                Helps understand impact in percentage terms.

        For example:
            If the coefficient for "daily junk food intake" is -0.5, it means eating more junk food 
            decreases the chnaces of loosing weight.
"""

# %%
#Practical Question

# %%
#Q1. Write a Python program that loads a dataset, splits it into training and testing sets, applies Logistic 
#    Regression, and prints the model accuracy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df = pd.DataFrame(data.data, columns= data.feature_names)
df['target'] = data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
#for binary classification>> two class needed>> so we filter out two class
df.target.unique()
# Out:
# array([0, 1, 2])

# %%
df = df[df['target'] != 2]

# %%
df
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
#     target
# 0        0
# 1        0
# ...

# %%
# split into X and Y
X = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
#splitting into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.20, random_state=1)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80, 4), (20, 4), (80,), (20,))

# %%
#model training
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 0, 1, 1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 0, 1, 0])

# %%
#evaluation metric
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
#Q2. Write a Python program to apply L1 regularization (Lasso) on a dataset using LogisticRegression(penalty='l1') 
#    and print the model accuracy

# %%
from sklearn.datasets import load_iris

# %%
df = pd.DataFrame(data.data, columns= data.feature_names)
df['target'] = data.target

# %%
#for binary classification>> two class needed>> so we filter out two class
df.target.unique()

# %%
df = df[df['target'] != 2]

# %%
# split into X and Y
X = df.iloc[:, :-1]
y = df.iloc[:,-1]

# %%
#training test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
#model training
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty= 'l1', solver = 'liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
y_pred = model.predict(X_test)

# %%
# metric evalutaion

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
#Q3. Write a Python program to train Logistic Regression with L2 regularization (Ridge) using 
#    LogisticRegression(penalty='l2'). Print model accuracy and coefficients.

from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#model training
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='l2', solver = 'liblinear')

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
model.coef_
# Out:
# array([[ 0.17014619, -0.63695275,  0.45954044, -0.44866988,  0.19442613,
#         -0.11805282, -0.402176  ,  0.01417294, -0.51635184,  0.23655351]])

# %%
y_pred = model.predict(X_test)

# %%
# metric evaluation
accu = accuracy_score(y_test,y_pred)
print(f"Model accuracy is {accu}")
# Out:
# Model accuracy is 0.825

# %%
#Q4. Write a Python program to train Logistic Regression with Elastic Net Regularization (penalty='elasticnet')

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#model training
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='elasticnet', solver = 'saga', l1_ratio=0.5)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(l1_ratio=0.5, penalty='elasticnet', solver='saga')

# %%
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([[ 0.15933293, -0.58211195,  0.4342296 , -0.49806147,  0.11863242,
#         -0.13386866, -0.40018709,  0.        , -0.59087518,  0.22368841]])

# %%
#Q5. Write a Python program to train a Logistic Regression model for multiclass classification using 
#    multi_class='ovr'

from sklearn.datasets import load_digits

# %%
data = load_digits()

# %%
print(data.DESCR)
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 1797
# :Number of Attributes: 64
# :Attribute Information: 8x8 image of integer pixels in the range 0..16.
# :Missing Attribute Values: None
# :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
# :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# ...

# %%
X = data.data
y = data.target

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2 , random_state=1)

# %%
#model training
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(multi_class= 'ovr', solver= 'liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
y_pred = model.predict(X_test)

# %%
a =accuracy_score(y_test, y_pred)
print(f'The accuracy of the model is {round(a,2)}')
# Out:
# The accuracy of the model is 0.97

# %%
#Q6. Write a Python program to apply GridSearchCV to tune the hyperparameters (C and penalty) of Logistic 
#    Regression. Print the best parameters and accuracy

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#hyperparameter tuning
#gridsearchcv
from sklearn.model_selection import GridSearchCV

# %%
params = {'penalty': ('l1','l2','elasticnet') , 'C' : (1,2,10,20,30,40)}

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
clf = GridSearchCV(model, param_grid= params, cv= 5, verbose= 2)

# %%
clf
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': (1, 2, 10, 20, 30, 40),
#                          'penalty': ('l1', 'l2', 'elasticnet')},
#              verbose=2)

# %%
clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ....................................C=1, penalty=l1; total time=   0.0s
# [CV] END ....................................C=1, penalty=l1; total time=   0.0s
# [CV] END ....................................C=1, penalty=l1; total time=   0.0s
# [CV] END ....................................C=1, penalty=l1; total time=   0.0s
# [CV] END ....................................C=1, penalty=l1; total time=   0.0s
# [CV] END ....................................C=1, penalty=l2; total time=   0.0s
# [CV] END ....................................C=1, penalty=l2; total time=   0.0s
# [CV] END ....................................C=1, penalty=l2; total time=   0.0s
# [CV] END ....................................C=1, penalty=l2; total time=   0.0s
# [CV] END ....................................C=1, penalty=l2; total time=   0.0s
# [CV] END ............................C=1, penalty=elasticnet; total time=   0.0s
# ...

# %%
clf.best_params_
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
model = LogisticRegression(C= 1, penalty='l2')

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
y_pred = model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(f'The accuracy of best parmas is {acc}')
# Out:
# The accuracy of best parmas is 0.825

# %%
#Q7. Write a Python program to evaluate Logistic Regression using Stratified K-Fold Cross-Validation. Print the average accuracy.
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
# initializa logistic regression model
model = LogisticRegression(penalty='l2', solver='liblinear')

# %%
# Stratified K-Fold Cross-validation
from sklearn.model_selection import StratifiedKFold, cross_val_score

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# %%
#perform cross_validation and compute accuracy
accuracies = cross_val_score(model,X,y, cv= skf, scoring='accuracy')

# %%
accuracies
# Out:
# array([0.845, 0.75 , 0.82 , 0.79 , 0.82 ])

# %%
#average accuracy is
print(f"Average accuracy :{np.mean(accuracies)}")
# Out:
# Average accuracy :0.805

# %%
#Q8. Write a Python program to load a dataset from a CSV file, apply Logistic Regression, and evaluate its 
#    accuracy.

#load the dataset
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
#perfrom EDA
df.isna().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df.dtypes
# Out:
# name                  object
# selling_price          int64
# year                   int64
# seller_type           object
# owner                 object
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %%
df = df.dropna(subset=['ex_showroom_price'])

# %%
df['owner'].unique()
# Out:
# array(['1st owner', '2nd owner', '3rd owner', '4th owner'], dtype=object)

# %%
#convert categorical column into numerical
categorical_col = ['owner','seller_type']
label_encoders = {}
from sklearn.preprocessing import LabelEncoder

# %%
for col in categorical_col:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])

# %%
df = df.drop(columns= 'name')

# %%
df.dtypes
# Out:
# selling_price          int64
# year                   int64
# seller_type            int32
# owner                  int32
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %%
#split into X and y
X = df.drop(columns= 'selling_price')
#for binary classification
y = (df['selling_price']> df['selling_price'].median()).astype(int)

# %%
y
# Out:
# 2       1
# 3       1
# 5       0
# 6       1
# 9       1
#        ..
# 1056    0
# 1057    0
# 1058    0
# 1059    0
# 1060    0
# Name: selling_price, Length: 626, dtype: int32

# %%
#split dataset into training and testing set
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
#model training
model = LogisticRegression(penalty='l2',solver='liblinear')

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
#make prediction
y_pred = model.predict(X_test)

# %%
#calculate the accuracy
accuracy_score(y_test, y_pred)
# Out:
# 0.7857142857142857

# %%
#Q9. Write a Python program to apply RandomizedSearchCV for tuning hyperparameters (C, penalty, solver) in 
#    Logistic Regression. Print the best parameters and accuracy

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#hyperparameter tuning
#gridsearchcv
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'penalty': ('l1','l2','elasticnet') , 'C' : (1,2,10,20,30,40)}

# %%
# model
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
random_clf = RandomizedSearchCV(model, param_distributions= params, n_iter= 10, cv= 5)

# %%
random_clf
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(),
#                    param_distributions={'C': (1, 2, 10, 20, 30, 40),
#                                         'penalty': ('l1', 'l2', 'elasticnet')})

# %%
random_clf.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(),
#                    param_distributions={'C': (1, 2, 10, 20, 30, 40),
#                                         'penalty': ('l1', 'l2', 'elasticnet')})

# %%
random_clf.best_params_
# Out:
# {'penalty': 'l2', 'C': 20}

# %%
#build ml model with this parameter

model = LogisticRegression(penalty='l2',C= 20 )

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=20)

# %%
#make predition
y_pred = model.predict(X_test)

# %%
ac = accuracy_score(y_test, y_pred)
print(f'Accuracy is {ac}')
# Out:
# Accuracy is 0.825

# %%
#Q10. Write a Python program to implement One-vs-One (OvO) Multiclass Logistic Regression and print accuracy.
from sklearn.multiclass import OneVsOneClassifier

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 3, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#train One vs one logistic regression
model = OneVsOneClassifier(LogisticRegression())

# %%
model.fit(X_train,y_train)
# Out:
# OneVsOneClassifier(estimator=LogisticRegression())

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.715

# %%
#Q11.  Write a Python program to train a Logistic Regression model and visualize the confusion matrix for binary classification

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
# evaluation metrics
from sklearn.metrics import confusion_matrix

# %%
conf_matrix = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(conf_matrix, annot = True)
plt.ylabel('Predicted')
plt.xlabel("Actual")
plt.title('Confusion Matrix')
plt.show()

# %%
#Q12 Write a Python program to train a Logistic Regression model and evaluate its performance using Precision, 
#    Recall, and F1-Score

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_proba = model.predict_proba(X_test)[:,1]

# %%
y_pred_proba
# Out:
# array([0.98410215, 0.15733928, 0.29548563, 0.13456016, 0.5636631 ,
#        0.08952626, 0.96607784, 0.31216935, 0.11916319, 0.96231278,
#        0.07528142, 0.42568004, 0.73355127, 0.23756702, 0.59119236,
#        0.6844788 , 0.95717137, 0.86931866, 0.97485839, 0.06992356,
#        0.45459622, 0.96249507, 0.81921423, 0.09653146, 0.91923184,
#        0.55764993, 0.14576764, 0.46233792, 0.49221641, 0.16962645,
#        0.24712383, 0.77853237, 0.09474567, 0.64952045, 0.96363796,
#        0.98124136, 0.99014257, 0.05049051, 0.0307142 , 0.48271716,
#        0.0792749 , 0.35647405, 0.01860321, 0.43225425, 0.276453  ,
#        0.17309028, 0.10617348, 0.37117309, 0.29267453, 0.04786668,
#        0.12582128, 0.04210657, 0.65516811, 0.98390216, 0.60498782,
#        0.10145739, 0.07451593, 0.17119768, 0.98681655, 0.97323921,
#        0.99617578, 0.91084282, 0.88768326, 0.35549884, 0.94894635,
#        0.19218325, 0.05533793, 0.09950113, 0.48708028, 0.73347329,
# ...

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
thresholds = np.linspace(0,1,100)
precisions = []
recalls = []
f1s = []


for threshold in thresholds:
    y_pred_threshold = (y_pred_proba >= threshold).astype(int)
    precision = precision_score(y_test, y_pred_threshold)
    recall = recall_score(y_test, y_pred_threshold)
    f1 = f1_score(y_test, y_pred_threshold)
    precisions.append(precision)
    recalls.append(recall)
    f1s.append(f1)

# %%
plt.plot(thresholds, precisions, label = 'Precision')
plt.plot(thresholds,recalls, label = 'Recall')
plt.plot(thresholds,f1s, label = 'F1')
plt.title("Precision, Recall, F1-score Vs Threshold Probability")
plt.legend()
plt.show()

# %%
#Q13. Write a Python program to train a Logistic Regression model on imbalanced data and apply class weights to 
#    improve model performance

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1, weights=[0.9,0.1])

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2 , random_state=1, stratify=y)

# %%
#model training
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight='balanced', solver='liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', solver='liblinear')

# %%
y_pred = model.predict(X_test)

# %%
#evaluation metric

precision_score(y_test, y_pred)
# Out:
# 0.23214285714285715

# %%
recall_score(y_test, y_pred)
# Out:
# 0.6190476190476191

# %%
#Q14.  Write a Python program to train Logistic Regression on the Titanic dataset, handle missing values, and evaluate performance.
df = sns.load_dataset("titanic")

# %%
#drop irrelevant column
df = df.drop(columns=['embark_town', 'deck','alive','who','class'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500        S        True
# 1         1       1  female  38.0      1      0  71.2833        C       False
# 2         1       3  female  26.0      0      0   7.9250        S       False
# 3         1       1  female  35.0      1      0  53.1000        S       False
# 4         0       3    male  35.0      0      0   8.0500        S        True
#
#    alone
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
df.isna().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age           177
# sibsp           0
# parch           0
# fare            0
# embarked        2
# adult_male      0
# alone           0
# dtype: int64

# %%
df['age'].fillna(df['age'].median(), inplace = True)
df['embarked'].fillna(df['embarked'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# adult_male    0
# alone         0
# dtype: int64

# %%
df.dtypes
# Out:
# survived        int64
# pclass          int64
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# fare          float64
# embarked       object
# adult_male       bool
# alone            bool
# dtype: object

# %%
df['alone'] = df['alone'].astype(int)
df['adult_male'] = df['adult_male'].astype(int)

# %%
#convert categorical column into numerical
categ_col = ['sex','embarked']
label_encoders = {}

# %%
from sklearn.preprocessing import LabelEncoder
for col in categ_col:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])

# %%
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  adult_male  \
# 0         0       3    1  22.0      1      0   7.2500         2           1
# 1         1       1    0  38.0      1      0  71.2833         0           0
# 2         1       3    0  26.0      0      0   7.9250         2           0
# 3         1       1    0  35.0      1      0  53.1000         2           0
# 4         0       3    1  35.0      0      0   8.0500         2           1
#
#    alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
# split into X and Y
X = df.drop(columns=['survived'])
y = df['survived']

# %%
# split the data set into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state=1, stratify=y)

# %%
# model training
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#make prediction
y_pred = model.predict(X_test)

# %%
# evaluate performance metrics
acc= accuracy_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
re = recall_score(y_test,y_pred)
f1 = f1_score(y_test, y_pred)

# %%
print(f"Accuracy: {acc}")
print(f"Precisions: {pre}")
print(f"Recall: {re}")
print(f"F1-Score: {f1}")
# Out:
# Accuracy: 0.8268156424581006
# Precisions: 0.796875
# Recall: 0.7391304347826086
# F1-Score: 0.7669172932330827

# %%
#Q15. Write a Python program to apply feature scaling (Standardization) before training a Logistic Regression 
#     model. Evaluate its accuracy and compare results with and without scaling

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training without scaling
model_without_scaling = LogisticRegression()

# %%
model_without_scaling.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# prediction
y_pred_without_scaling = model_without_scaling.predict(X_test)

# %%
#accuracy score
acc_without_scaling = accuracy_score(y_test, y_pred_without_scaling)

# %%
acc_without_scaling
# Out:
# 0.825

# %%
#standaradization
from sklearn.preprocessing import StandardScaler
Scaler  = StandardScaler()
X_train_scaled = Scaler.fit_transform(X_train)
X_test_scaled = Scaler.transform(X_test)

# %%
#model trraing with scaling

model_with_scaling = LogisticRegression()

# %%
model_with_scaling.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
#prediction with scaling
y_pred_scaling = model_with_scaling.predict(X_test_scaled)

# %%
#accuracy score
acc_without_scaling = accuracy_score(y_test, y_pred_scaling)

# %%
acc_without_scaling
# Out:
# 0.825

# %%
#Q16.  Write a Python program to train Logistic Regression and evaluate its performance using ROC-AUC score.

X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# prediction proabbilities for oistive class
y_pred_proba = model.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %%
roc_auc
# Out:
# 0.8714371738257727

# %%
# Roc Curve
fpr, tpr, thrsholds = roc_curve(y_test,y_pred_proba)

# %%
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, label = f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0,1],[0,1])
plt.title('ROC Curve')
plt.xlabel('False Positive rate (FPR)')
plt.ylabel("true positive rate (TPR)")
plt.legend()
plt.show()

# %%
#Q17. Write a Python program to train Logistic Regression using a custom learning rate (C=0.5) and evaluate accuracy.

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression(C = 0.5, solver = 'liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.5, solver='liblinear')

# %%
y_pred = model.predict(X_test)

# %%
acc= accuracy_score(y_test, y_pred)

# %%
print(F"Model Accuracy : {acc}")
# Out:
# Model Accuracy : 0.825

# %%
#Q18. Write a Python program to train Logistic Regression and identify important features based on model coefficients

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[ 0.17113268, -0.63675163,  0.46098937, -0.44894152,  0.19424901,
#         -0.11809296, -0.40387356,  0.01522666, -0.51693563,  0.23806169]])

# %%
# absolute coefficients
imp_feature = np.abs(model.coef_[0])

# %%
imp_feature
# Out:
# array([0.17113268, 0.63675163, 0.46098937, 0.44894152, 0.19424901,
#        0.11809296, 0.40387356, 0.01522666, 0.51693563, 0.23806169])

# %%
# Rank feature by importance
sort = np.argsort(imp_feature)[::-1]
features = [f"Feature {i}" for i in range(X.shape[1])]

# %%
for idx in sort:
    print(F"features[idx]: {imp_feature[idx]}")
# Out:
# features[idx]: 0.6367516286997881
# features[idx]: 0.5169356297502847
# features[idx]: 0.4609893662137608
# features[idx]: 0.4489415239600187
# features[idx]: 0.40387355641001094
# features[idx]: 0.23806168572893266
# features[idx]: 0.19424901150369484
# features[idx]: 0.17113267589719858
# features[idx]: 0.11809295891208593
# features[idx]: 0.015226664547597914

# %%
#Q19.  Write a Python program to train Logistic Regression and evaluate its performance using Cohen’s Kappa Score

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.6518798488163915

# %%
#Q20.  Write a Python program to train Logistic Regression and visualize the Precision-Recall Curve for binary classification

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_proba = model.predict_proba(X_test)[:,1]

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
precison , recall, thresholds = precision_recall_curve(y_test, y_pred_proba)

# %%
# compute average score
av_precison = average_precision_score(y_test, y_pred_proba)

# %%
plt.plot(recall,precison, label= (f"Precison-Recall Curve (AP = {av_precison:.2f})"))
plt.title("Precision_Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.show()

# %%
#Q21. Write a Python program to train Logistic Regression with different solvers (liblinear, saga, lbfgs) and compare 
#    their accuracy

# %%
X,y = make_classification(n_samples= 1000, n_features= 10, n_redundant= 5, n_informative= 5, n_classes= 2, random_state= 1)

# %%
#split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.2, random_state=1)

# %%
# model training 
model = LogisticRegression(solver = 'liblinear')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = model.predict(X_test)

# %%
#accuracy solver = liblinear
acc_liblinear = accuracy_score(y_test,y_pred)

# %%
# model training 
model = LogisticRegression(solver = 'saga', max_iter= 500)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500, solver='saga')

# %%
y_pred = model.predict(X_test)

# %%
#accuracy solver = saga
acc_saga = accuracy_score(y_test,y_pred)

# %%
acc_saga
# Out:
# 0.825

# %%
#accuracy = lbfgs
# model training 
model = LogisticRegression(solver = 'lbfgs')

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
#accuracy solver = lbfgs
acc_lbfgs = accuracy_score(y_test,y_pred)

# %%
acc_lbfgs
# Out:
# 0.825

# %%
# comparing accuracu
print(f'solver : liblinear, Accuracy {acc_liblinear}')
print(f'solver : saga, Accuracy {acc_saga}')
print(f'solver : lbfgs, Accuracy {acc_lbfgs}')
# Out:
# solver : liblinear, Accuracy 0.825
# solver : saga, Accuracy 0.825
# solver : lbfgs, Accuracy 0.825

# %%
#Q22. Write a Python program to train Logistic Regression and evaluate its performance using Matthews 
#    Correlation Coefficient (MCC)
X, y = make_classification(n_samples=1000, n_features=10, n_redundant=5, n_informative=5, n_classes=2, random_state=1)

# %%
#split the data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import matthews_corrcoef

# %%
matthews_corrcoef(y_test,y_pred)
# Out:
# 0.659258339857608

# %%
#Q23 Write a Python program to train Logistic Regression on both raw and standardized data. Compare their 
#    accuracy to see the impact of feature scaling

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_redundant=5, n_informative=5, n_classes=2, random_state=1)

# %%
#split the data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
raw_acc = accuracy_score(y_test, y_pred)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
#logistic regression model on Standardized data
model_scaled  = LogisticRegression()

# %%
model_scaled.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_scaled = model_scaled.predict(X_test_scaled)

# %%
scaled_acc = accuracy_score(y_pred, y_pred_scaled)

# %%
if scaled_acc > raw_acc:
    print("Feature Scaling improved accuracy")
elif scaled_acc == raw_acc:
    print("No change in accuracy")
# Out:
# Feature Scaling improved accuracy

# %%
#Q24. Write a Python program to train Logistic Regression and find the optimal C (regularization strength) using 
#     cross-validation

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_redundant=5, n_informative=5, n_classes=2, random_state=1)

# %%
#split the data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#different C values
C_values = np.logspace(-2,2,5)
best_c = None
best_score = 0

# %%
from sklearn.model_selection import cross_val_score

# %%
for C in C_values:
    model = LogisticRegression(C = C, solver= 'liblinear')
    score = np.mean(cross_val_score(model, X_train,y_train, cv = 5))
    print(f"C = {C:.2f}, Accuracy = {score:.2f}")

    if score > best_score:
        best_c = C
        best_score = score
# Out:
# C = 0.01, Accuracy = 0.82
# C = 0.10, Accuracy = 0.80
# C = 1.00, Accuracy = 0.81
# C = 10.00, Accuracy = 0.81
# C = 100.00, Accuracy = 0.81

# %%
print(f"best C value is: {best_c}, Best Accuracy: {best_score:.2f}")
# Out:
# best C value is: 0.01, Best Accuracy: 0.82

# %%
#Q25. Write a Python program to train Logistic Regression, save the trained model using joblib, and load it again to 
#    make predictions
import joblib

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_redundant=5, n_informative=5, n_classes=2, random_state=1)

# %%
#split the data into training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#save the model
joblib.dump(model, "logistic_model.pkl")
# Out:
# ['logistic_model.pkl']

# %%
#load the model
model_load = joblib.load("logistic_model.pkl")

# %%
model_load
# Out:
# LogisticRegression()

# %%
y_pred = model_load.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.825
